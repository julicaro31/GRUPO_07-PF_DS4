# %% [markdown]
# ### POPULATION

# %% [markdown]
# Source of data : https://www.census.gov/data/tables/time-series/demo/popest/2020s-total-cities-and-towns.html#ds

# %%
# Import libraries
import pandas as pd
import numpy as  np

# %% [markdown]
# ### We extract the data from our S3 bucket

# %%
from private.s3_aws import access_key, secret_access_key

# %%
# Read files
# Table #1
population2010 = pd.read_csv(f"s3://rawdatagrupo07/SUB-EST2020_ALL.csv",
    storage_options={
        "key": access_key,
        "secret": secret_access_key
    },encoding = "ISO-8859-1"
)

print('Shape table 2010-2020 : ' ,  population2010.shape)
#Table #2
population2021 = pd.read_csv(f"s3://rawdatagrupo07/sub-est2021_all.csv",
    storage_options={
        "key": access_key,
        "secret": secret_access_key
    },engine='python',encoding='latin1'
)
print('Shape table 2021: ', population2021.shape)
# Out:
# Shape table 2010-2020 :  (81415, 24)
# Shape table 2021:  (81416, 13)

# %%
population2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81415 entries, 0 to 81414
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SUMLEV             81415 non-null  int64
#  1   STATE              81415 non-null  int64
#  2   COUNTY             81415 non-null  int64
#  3   PLACE              81415 non-null  int64
#  4   COUSUB             81415 non-null  int64
#  5   CONCIT             81415 non-null  int64
#  6   PRIMGEO_FLAG       81415 non-null  int64
#  7   FUNCSTAT           81415 non-null  object
#  8   NAME               81415 non-null  object
#  9   STNAME             81415 non-null  object
#  10  CENSUS2010POP      81415 non-null  object
#  11  ESTIMATESBASE2010  81415 non-null  int64
#  12  POPESTIMATE2010    81415 non-null  int64
#  13  POPESTIMATE2011    81415 non-null  int64
#  14  POPESTIMATE2012    81415 non-null  int64
#  15  POPESTIMATE2013    81415 non-null  int64
#  16  POPESTIMATE2014    81415 non-null  int64
#  17  POPESTIMATE2015    81415 non-null  int64
#  18  POPESTIMATE2016    81415 non-null  int64
#  19  POPESTIMATE2017    81415 non-null  int64
#  20  POPESTIMATE2018    81415 non-null  int64
#  21  POPESTIMATE2019    81415 non-null  int64
#  22  POPESTIMATE042020  81415 non-null  int64
#  23  POPESTIMATE2020    81415 non-null  int64
# dtypes: int64(20), object(4)
# memory usage: 14.9+ MB

# %%
population2010[population2010.duplicated()]
# Out:
# Empty DataFrame
# Columns: [SUMLEV, STATE, COUNTY, PLACE, COUSUB, CONCIT, PRIMGEO_FLAG, FUNCSTAT, NAME, STNAME, CENSUS2010POP, ESTIMATESBASE2010, POPESTIMATE2010, POPESTIMATE2011, POPESTIMATE2012, POPESTIMATE2013, POPESTIMATE2014, POPESTIMATE2015, POPESTIMATE2016, POPESTIMATE2017, POPESTIMATE2018, POPESTIMATE2019, POPESTIMATE042020, POPESTIMATE2020]
# Index: []
#
# [0 rows x 24 columns]

# %%
population2021[population2021.duplicated()]
# Out:
# Empty DataFrame
# Columns: [SUMLEV, STATE, COUNTY, PLACE, COUSUB, CONCIT, PRIMGEO_FLAG, FUNCSTAT, NAME, STNAME, ESTIMATESBASE2020, POPESTIMATE2020, POPESTIMATE2021]
# Index: []

# %%
population2010.columns
# Out:
# Index(['SUMLEV', 'STATE', 'COUNTY', 'PLACE', 'COUSUB', 'CONCIT',
#        'PRIMGEO_FLAG', 'FUNCSTAT', 'NAME', 'STNAME', 'CENSUS2010POP',
#        'ESTIMATESBASE2010', 'POPESTIMATE2010', 'POPESTIMATE2011',
#        'POPESTIMATE2012', 'POPESTIMATE2013', 'POPESTIMATE2014',
#        'POPESTIMATE2015', 'POPESTIMATE2016', 'POPESTIMATE2017',
#        'POPESTIMATE2018', 'POPESTIMATE2019', 'POPESTIMATE042020',
#        'POPESTIMATE2020'],
#       dtype='object')

# %%
# Dataframe population2010
population2010['SUMLEV']= population2010['SUMLEV'].astype(str)
population2010['STATE']= population2010['STATE'].astype(str)
population2010['COUNTY']= population2010['COUNTY'].astype(str)
population2010[ 'PLACE']= population2010[ 'PLACE'].astype(str)
population2010['COUSUB']= population2010['COUSUB'].astype(str)
population2010['CONCIT']= population2010['CONCIT'].astype(str)
population2010['PRIMGEO_FLAG']= population2010['PRIMGEO_FLAG'].astype(str)

#Dataframe population2021
population2021['SUMLEV']= population2021['SUMLEV'].astype(str)
population2021['STATE']= population2021['STATE'].astype(str)
population2021['COUNTY']= population2021['COUNTY'].astype(str)
population2021[ 'PLACE']= population2021[ 'PLACE'].astype(str)
population2021['COUSUB']= population2021['COUSUB'].astype(str)
population2021['CONCIT']= population2021['CONCIT'].astype(str)
population2021['PRIMGEO_FLAG']= population2021['PRIMGEO_FLAG'].astype(str)

# %%
# Create a new column 'Indicator' fot two tables
population2010['Indicator']= population2010[['SUMLEV','STATE','COUNTY','PLACE','COUSUB','CONCIT','PRIMGEO_FLAG','FUNCSTAT']].apply(''.join, axis = 1)

population2021['Indicator']= population2021[['SUMLEV','STATE','COUNTY','PLACE','COUSUB','CONCIT','PRIMGEO_FLAG','FUNCSTAT']].apply(''.join, axis = 1)

# %%
population2010.columns
# Out:
# Index(['SUMLEV', 'STATE', 'COUNTY', 'PLACE', 'COUSUB', 'CONCIT',
#        'PRIMGEO_FLAG', 'FUNCSTAT', 'NAME', 'STNAME', 'CENSUS2010POP',
#        'ESTIMATESBASE2010', 'POPESTIMATE2010', 'POPESTIMATE2011',
#        'POPESTIMATE2012', 'POPESTIMATE2013', 'POPESTIMATE2014',
#        'POPESTIMATE2015', 'POPESTIMATE2016', 'POPESTIMATE2017',
#        'POPESTIMATE2018', 'POPESTIMATE2019', 'POPESTIMATE042020',
#        'POPESTIMATE2020', 'Indicator'],
#       dtype='object')

# %%
population= pd.merge(population2010,population2021, how = 'inner', left_on='Indicator', right_on='Indicator')
population.head(10)
# Out:
#   SUMLEV_x STATE_x COUNTY_x PLACE_x COUSUB_x CONCIT_x PRIMGEO_FLAG_x  \
# 0       40       1        0       0        0        0              0
# 1      162       1        0     124        0        0              0
# 2      162       1        0     460        0        0              0
# 3      162       1        0     484        0        0              0
# 4      162       1        0     676        0        0              0
# 5      162       1        0     820        0        0              0
# 6      162       1        0     988        0        0              0
# 7      162       1        0    1132        0        0              0
# 8      162       1        0    1228        0        0              0
# 9      162       1        0    1396        0        0              0
#
#   FUNCSTAT_x               NAME_x STNAME_x  ... PLACE_y  COUSUB_y  CONCIT_y  \
# 0          A              Alabama  Alabama  ...       0         0         0
# 1          A       Abbeville city  Alabama  ...     124         0         0
# 2          A      Adamsville city  Alabama  ...     460         0         0
# 3          A         Addison town  Alabama  ...     484         0         0
# 4          A           Akron town  Alabama  ...     676         0         0
# 5          A       Alabaster city  Alabama  ...     820         0         0
# 6          A     Albertville city  Alabama  ...     988         0         0
# 7          A  Alexander City city  Alabama  ...    1132         0         0
# 8          A      Aliceville city  Alabama  ...    1228         0         0
# 9          A         Allgood town  Alabama  ...    1396         0         0
#
#    PRIMGEO_FLAG_y  FUNCSTAT_y               NAME_y  STNAME_y  \
# 0               0           A              Alabama   Alabama
# 1               0           A       Abbeville city   Alabama
# 2               0           A      Adamsville city   Alabama
# 3               0           A         Addison town   Alabama
# 4               0           A           Akron town   Alabama
# 5               0           A       Alabaster city   Alabama
# 6               0           A     Albertville city   Alabama
# 7               0           A  Alexander City city   Alabama
# 8               0           A      Aliceville city   Alabama
# 9               0           A         Allgood town   Alabama
#
#    ESTIMATESBASE2020  POPESTIMATE2020_y  POPESTIMATE2021
# 0            5024279            5024803          5039877
# 1               2368               2368             2379
# 2               4372               4356             4294
# 3                664                664              668
# 4                227                227              226
# 5              33360              33381            33676
# 6              22390              22385            22522
# 7              14807              14761            14618
# 8               2175               2166             2123
# 9                544                543              545
#
# [10 rows x 38 columns]

# %%
population.columns
# Out:
# Index(['SUMLEV_x', 'STATE_x', 'COUNTY_x', 'PLACE_x', 'COUSUB_x', 'CONCIT_x',
#        'PRIMGEO_FLAG_x', 'FUNCSTAT_x', 'NAME_x', 'STNAME_x', 'CENSUS2010POP',
#        'ESTIMATESBASE2010', 'POPESTIMATE2010', 'POPESTIMATE2011',
#        'POPESTIMATE2012', 'POPESTIMATE2013', 'POPESTIMATE2014',
#        'POPESTIMATE2015', 'POPESTIMATE2016', 'POPESTIMATE2017',
#        'POPESTIMATE2018', 'POPESTIMATE2019', 'POPESTIMATE042020',
#        'POPESTIMATE2020_x', 'Indicator', 'SUMLEV_y', 'STATE_y', 'COUNTY_y',
#        'PLACE_y', 'COUSUB_y', 'CONCIT_y', 'PRIMGEO_FLAG_y', 'FUNCSTAT_y',
#        'NAME_y', 'STNAME_y', 'ESTIMATESBASE2020', 'POPESTIMATE2020_y',
#        'POPESTIMATE2021'],
#       dtype='object')

# %%
population = population[['NAME_x', 'STNAME_x', 'POPESTIMATE2010', 'POPESTIMATE2011',
       'POPESTIMATE2012', 'POPESTIMATE2013', 'POPESTIMATE2014',
       'POPESTIMATE2015', 'POPESTIMATE2016', 'POPESTIMATE2017',
       'POPESTIMATE2018', 'POPESTIMATE2019',
       'POPESTIMATE2020_x', 'POPESTIMATE2021']]

# %%
population.head(2)
# Out:
#            NAME_x STNAME_x  POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# 0         Alabama  Alabama          4785514          4799642          4816632
# 1  Abbeville city  Alabama             2699             2694             2645
#
#    POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015  POPESTIMATE2016  \
# 0          4831586          4843737          4854803          4866824
# 1             2629             2610             2602             2587
#
#    POPESTIMATE2017  POPESTIMATE2018  POPESTIMATE2019  POPESTIMATE2020_x  \
# 0          4877989          4891628          4907965            4921532
# 1             2578             2565             2555               2553
#
#    POPESTIMATE2021
# 0          5039877
# 1             2379

# %%
population['NAME_x']= population['NAME_x'].str.strip('city')
population['NAME_x']= population['NAME_x'].str.strip()
population['NAME_x']
# Out:
# 0                         Alabama
# 1                       Abbeville
# 2                      Adamsville
# 3                    Addison town
# 4                      Akron town
#                    ...
# 81553    Balance of Washakie Coun
# 81554                 Weston Coun
# 81555                   Newcastle
# 81556                  Upton town
# 81557      Balance of Weston Coun
# Name: NAME_x, Length: 81558, dtype: object

# %%
population['NAME_x']= population['NAME_x'].str.strip('town')
population['NAME_x']= population['NAME_x'].str.strip()
population['NAME_x']
# Out:
# 0                        Alabama
# 1                      Abbeville
# 2                     Adamsville
# 3                        Addison
# 4                          Akron
#                   ...
# 81553    Balance of Washakie Cou
# 81554                 Weston Cou
# 81555                  Newcastle
# 81556                      Upton
# 81557      Balance of Weston Cou
# Name: NAME_x, Length: 81558, dtype: object

# %%
#Change names  of colums NAME_x, STNAME_x
population = population.rename(columns= {'NAME_x':'City'})
population = population.rename(columns= {'STNAME_x':'State'})
population = population.rename(columns= {'POPESTIMATE2020_x':'POPESTIMATE2020'})

# %%
population.columns
# Out:
# Index(['City', 'State', 'POPESTIMATE2010', 'POPESTIMATE2011',
#        'POPESTIMATE2012', 'POPESTIMATE2013', 'POPESTIMATE2014',
#        'POPESTIMATE2015', 'POPESTIMATE2016', 'POPESTIMATE2017',
#        'POPESTIMATE2018', 'POPESTIMATE2019', 'POPESTIMATE2020',
#        'POPESTIMATE2021'],
#       dtype='object')

# %%
us_state_to_abbrev = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
    "United States": "US"}

# %%
population['State'] = population.State.astype(str).apply(lambda x: us_state_to_abbrev[x])

# %%
population['State']
# Out:
# 0        AL
# 1        AL
# 2        AL
# 3        AL
# 4        AL
#          ..
# 81553    WY
# 81554    WY
# 81555    WY
# 81556    WY
# 81557    WY
# Name: State, Length: 81558, dtype: object

# %%
# Read cities.csv to normalize data
cities = pd.read_csv(f"s3://cleandatagrupo07/cities.csv",
        storage_options={
            "key": access_key,
            "secret": secret_access_key
        }
    )

# %%
cities.head(3)
# Out:
#           Unique_City_ID         City     County State
# 0   oak_grovechristianky    Oak Grove  Christian    KY
# 1  jarvisburgcurritucknc   Jarvisburg  Currituck    NC
# 2   mcminnvilleyamhillor  McMinnville    Yamhill    OR

# %%
df3 = pd.merge(cities, population, how = 'inner', on =['City', 'State'])

# %%
df3
# Out:
#              Unique_City_ID         City     County State  POPESTIMATE2010  \
# 0      oak_grovechristianky    Oak Grove  Christian    KY             7515
# 1      oak_grovechristianky    Oak Grove  Christian    KY             7515
# 2      mcminnvilleyamhillor  McMinnville    Yamhill    OR            32213
# 3      mcminnvilleyamhillor  McMinnville    Yamhill    OR            32213
# 4        oshkoshwinnebagowi      Oshkosh  Winnebago    WI            66323
# ...                     ...          ...        ...   ...              ...
# 22830     baxtercrow_wingmn       Baxter  Crow Wing    MN             7653
# 22831     baxtercrow_wingmn       Baxter  Crow Wing    MN             7653
# 22832     baxtercrow_wingmn       Baxter  Crow Wing    MN             7653
# 22833       benddeschutesor         Bend  Deschutes    OR            76658
# 22834       benddeschutesor         Bend  Deschutes    OR            76658
#
#        POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  \
# 0                 7430             7629             7496             7490
# 1                 7430             7629             7496             7490
# 2                32315            32415            32374            32667
# 3                32315            32415            32374            32667
# 4                66361            66867            66951            66810
# ...                ...              ...              ...              ...
# 22830             7656             7692             7742             7802
# 22831             7656             7692             7742             7802
# 22832             7656             7692             7742             7802
# 22833            77582            78637            80943            83581
# 22834            77582            78637            80943            83581
#
#        POPESTIMATE2015  POPESTIMATE2016  POPESTIMATE2017  POPESTIMATE2018  \
# 0                 7469             7372             7240             7320
# 1                 7469             7372             7240             7320
# 2                33012            33854            34207            34434
# 3                33012            33854            34207            34434
# 4                66707            66671            66736            66744
# ...                ...              ...              ...              ...
# 22830             7902             8178             8265             8323
# 22831             7902             8178             8265             8323
# 22832             7902             8178             8265             8323
# 22833            86345            90739            94667            97548
# 22834            86345            90739            94667            97548
#
#        POPESTIMATE2019  POPESTIMATE2020  POPESTIMATE2021
# 0                 7352             7369             7793
# 1                 7352             7369             7793
# 2                34674            35185            34666
# 3                34674            35185            34666
# 4                66933            66495            66607
# ...                ...              ...              ...
# 22830             8379             8483             8830
# 22831             8379             8483             8830
# 22832             8379             8483             8830
# 22833           100274           101886           102059
# 22834           100274           101886           102059
#
# [22835 rows x 16 columns]

# %%
df3.drop_duplicates(subset = ['Unique_City_ID'], keep= 'first')
# Out:
#              Unique_City_ID         City     County State  POPESTIMATE2010  \
# 0      oak_grovechristianky    Oak Grove  Christian    KY             7515
# 2      mcminnvilleyamhillor  McMinnville    Yamhill    OR            32213
# 4        oshkoshwinnebagowi      Oshkosh  Winnebago    WI            66323
# 9            garrettellistx      Garrett      Ellis    TX              810
# 11       mayesvillesumtersc   Mayesville     Sumter    SC              729
# ...                     ...          ...        ...   ...              ...
# 22824    sawmillscaldwellnc     Sawmills   Caldwell    NC             5205
# 22826       frederickweldco    Frederick       Weld    CO             8702
# 22828     deerfieldoneidany    Deerfield     Oneida    NY             4125
# 22829     baxtercrow_wingmn       Baxter  Crow Wing    MN             7653
# 22833       benddeschutesor         Bend  Deschutes    OR            76658
#
#        POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  \
# 0                 7430             7629             7496             7490
# 2                32315            32415            32374            32667
# 4                66361            66867            66951            66810
# 9                  814              814              821              826
# 11                 725              729              727              729
# ...                ...              ...              ...              ...
# 22824             5170             5151             5149             5126
# 22826             8830             8974             9121             9328
# 22828             4135             4135             4129             4110
# 22829             7656             7692             7742             7802
# 22833            77582            78637            80943            83581
#
#        POPESTIMATE2015  POPESTIMATE2016  POPESTIMATE2017  POPESTIMATE2018  \
# 0                 7469             7372             7240             7320
# 2                33012            33854            34207            34434
# 4                66707            66671            66736            66744
# 9                  839              848              853              869
# 11                 724              723              716              716
# ...                ...              ...              ...              ...
# 22824             5118             5134             5144             5153
# 22826             9543             9762             9908            10178
# 22828             4086             4067             4063             4064
# 22829             7902             8178             8265             8323
# 22833            86345            90739            94667            97548
#
#        POPESTIMATE2019  POPESTIMATE2020  POPESTIMATE2021
# 0                 7352             7369             7793
# 2                34674            35185            34666
# 4                66933            66495            66607
# 9                  880              891              854
# 11                 718              715              550
# ...                ...              ...              ...
# 22824             5164             5156             5036
# 22826            10695            11515            15761
# 22828             4063             4050             3939
# 22829             8379             8483             8830
# 22833           100274           101886           102059
#
# [11068 rows x 16 columns]

# %%
df3.drop(['City','County','State'],axis=1,inplace=True)

# %%
df3.drop_duplicates(subset=['Unique_City_ID'],inplace=True)

# %%
values = [i for i in range(2010,2022)]

# %%
keys = [f"POPESTIMATE{i}" for i in range(2010,2022)]

# %%
df3.rename(columns=dict(zip(keys, values)),inplace=True)

# %%
df_melt = pd.melt(df3, id_vars =['Unique_City_ID'], value_vars = values)

# %%
df_melt.rename(columns={'variable':'Year','value':'PopEstimate'},inplace=True)

# %%
df_melt.head()
# Out:
#          Unique_City_ID  Year  PopEstimate
# 0  oak_grovechristianky  2010         7515
# 1  mcminnvilleyamhillor  2010        32213
# 2    oshkoshwinnebagowi  2010        66323
# 3        garrettellistx  2010          810
# 4    mayesvillesumtersc  2010          729
